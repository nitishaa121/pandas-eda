# %% [markdown]
# ## Exploratory Analysis of Food Sales
# #### Nitisha Agarwal
# #### Aug 24, 3023
#
# Eventual goal: Understand customer sales patterns and identify trends relevant to potentially acquiring new customers.
# Kaggle Link: https://www.kaggle.com/datasets/ramjasmaurya/medias-cost-prediction-in-foodmart

# %% [markdown]
# 1. Import modules and read data
# 2. Initial Exploration: columns, dtypes, info, describe
# 3. Drop / Rename columns & get numeric cols
# 4. Missing values / duplicates / outlier detection
# 5. Create some important/relevant metrics as new columns
# 6. Boxplots / Pairplot / Correlation for important numeric variables
# 7. Guiding questions -- do some groupbys, look at distributions
# 8. Conclusions

# %% [markdown]
# ### 1. Import modules and read data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv("media prediction and its cost.csv")

# %% [markdown]
# ### 2. Initial Exploration

# %%
df.columns
# Out:
# Index(['food_category', 'food_department', 'food_family',
#        'store_sales(in millions)', 'store_cost(in millions)',
#        'unit_sales(in millions)', 'promotion_name', 'sales_country',
#        'marital_status', 'gender', 'total_children', 'education',
#        'member_card', 'occupation', 'houseowner', 'avg_cars_at home(approx)',
#        'avg. yearly_income', 'num_children_at_home',
#        'avg_cars_at home(approx).1', 'brand_name', 'SRP', 'gross_weight',
#        'net_weight', 'recyclable_package', 'low_fat', 'units_per_case',
#        'store_type', 'store_city', 'store_state', 'store_sqft', 'grocery_sqft',
#        'frozen_sqft', 'meat_sqft', 'coffee_bar', 'video_store', 'salad_bar',
#        'prepared_food', 'florist', 'media_type', 'cost'],
#       dtype='object')

# %%
df.iloc[:,10:22].head()
# Out:
#    total_children            education member_card      occupation houseowner  \
# 0             1.0  Partial High School      Normal  Skilled Manual          Y
# 1             0.0     Bachelors Degree      Silver    Professional          Y
# 2             4.0  Partial High School      Normal          Manual          N
# 3             2.0   High School Degree      Bronze          Manual          Y
# 4             0.0  Partial High School      Bronze  Skilled Manual          N
#
#    avg_cars_at home(approx) avg. yearly_income  num_children_at_home  \
# 0                       1.0        $10K - $30K                   1.0
# 1                       4.0        $50K - $70K                   0.0
# 2                       1.0        $10K - $30K                   0.0
# 3                       2.0        $30K - $50K                   2.0
# 4                       2.0        $30K - $50K                   0.0
#
#    avg_cars_at home(approx).1  brand_name   SRP  gross_weight
# 0                         1.0  Carrington  1.84         19.70
# 1                         4.0  Carrington  1.84         19.70
# 2                         1.0  Carrington  1.84         19.70
# 3                         2.0  Carrington  1.84         19.70
# 4                         2.0      Golden  1.36          7.12

# %%
df.shape
# Out:
# (60428, 40)

# %%
df.describe()
# Out:
#        store_sales(in millions)  store_cost(in millions)  \
# count              60428.000000             60428.000000
# mean                   6.541031                 2.619460
# std                    3.463047                 1.453009
# min                    0.510000                 0.163200
# 25%                    3.810000                 1.500000
# 50%                    5.940000                 2.385600
# 75%                    8.670000                 3.484025
# max                   22.920000                 9.726500
#
#        unit_sales(in millions)  total_children  avg_cars_at home(approx)  \
# count             60428.000000    60428.000000              60428.000000
# mean                  3.093169        2.533875                  2.200271
# std                   0.827677        1.490165                  1.109644
# min                   1.000000        0.000000                  0.000000
# 25%                   3.000000        1.000000                  1.000000
# 50%                   3.000000        3.000000                  2.000000
# 75%                   4.000000        4.000000                  3.000000
# max                   6.000000        5.000000                  4.000000
#
#        num_children_at_home  avg_cars_at home(approx).1           SRP  \
# count          60428.000000                60428.000000  60428.000000
# mean               0.829351                    2.200271      2.115258
# std                1.303424                    1.109644      0.932829
# min                0.000000                    0.000000      0.500000
# 25%                0.000000                    1.000000      1.410000
# 50%                0.000000                    2.000000      2.130000
# 75%                1.000000                    3.000000      2.790000
# max                5.000000                    4.000000      3.980000
#
#        gross_weight    net_weight  ...    store_sqft  grocery_sqft  \
# count  60428.000000  60428.000000  ...  60428.000000  60428.000000
# mean      13.806433     11.796289  ...  27988.477494  19133.799696
# std        4.622693      4.682986  ...   5701.022090   3987.395735
# min        6.000000      3.050000  ...  20319.000000  13305.000000
# 25%        9.700000      7.710000  ...  23593.000000  16232.000000
# 50%       13.600000     11.600000  ...  27694.000000  18670.000000
# 75%       17.700000     16.000000  ...  30797.000000  22123.000000
# max       21.900000     20.800000  ...  39696.000000  30351.000000
#
#         frozen_sqft     meat_sqft    coffee_bar   video_store     salad_bar  \
# count  60428.000000  60428.000000  60428.000000  60428.000000  60428.000000
# mean    5312.852552   3541.846280      0.612646      0.354157      0.587956
# std     1575.907263   1050.471635      0.487150      0.478261      0.492207
# min     2452.000000   1635.000000      0.000000      0.000000      0.000000
# 25%     4746.000000   3164.000000      0.000000      0.000000      0.000000
# 50%     5062.000000   3375.000000      1.000000      0.000000      1.000000
# 75%     5751.000000   3834.000000      1.000000      1.000000      1.000000
# max     9184.000000   6122.000000      1.000000      1.000000      1.000000
#
#        prepared_food       florist          cost
# count   60428.000000  60428.000000  60428.000000
# mean        0.587956      0.562603     99.262366
# std         0.492207      0.496069     30.011257
# min         0.000000      0.000000     50.790000
# 25%         0.000000      0.000000     69.650000
# 50%         1.000000      1.000000     98.520000
# 75%         1.000000      1.000000    126.620000
# max         1.000000      1.000000    149.750000
#
# [8 rows x 23 columns]

# %%
# What is suggested retail price distribution?
df.SRP.describe()
# Out:
# count    60428.000000
# mean         2.115258
# std          0.932829
# min          0.500000
# 25%          1.410000
# 50%          2.130000
# 75%          2.790000
# max          3.980000
# Name: SRP, dtype: float64

# %% [markdown]
# ### 3. Drop / Rename Columns & get numeric cols

# %%
df.columns
# Out:
# Index(['food_category', 'food_department', 'food_family',
#        'store_sales(in millions)', 'store_cost(in millions)',
#        'unit_sales(in millions)', 'promotion_name', 'sales_country',
#        'marital_status', 'gender', 'total_children', 'education',
#        'member_card', 'occupation', 'houseowner', 'avg_cars_at home(approx)',
#        'avg. yearly_income', 'num_children_at_home',
#        'avg_cars_at home(approx).1', 'brand_name', 'SRP', 'gross_weight',
#        'net_weight', 'recyclable_package', 'low_fat', 'units_per_case',
#        'store_type', 'store_city', 'store_state', 'store_sqft', 'grocery_sqft',
#        'frozen_sqft', 'meat_sqft', 'coffee_bar', 'video_store', 'salad_bar',
#        'prepared_food', 'florist', 'media_type', 'cost'],
#       dtype='object')

# %%
df = df.drop(columns=['avg_cars_at home(approx).1', 'gross_weight',
       'net_weight', 'recyclable_package', 'low_fat', 'units_per_case'])

# %%
df.columns
# Out:
# Index(['food_category', 'food_department', 'food_family',
#        'store_sales(in millions)', 'store_cost(in millions)',
#        'unit_sales(in millions)', 'promotion_name', 'sales_country',
#        'marital_status', 'gender', 'total_children', 'education',
#        'member_card', 'occupation', 'houseowner', 'avg_cars_at home(approx)',
#        'avg. yearly_income', 'num_children_at_home', 'brand_name', 'SRP',
#        'store_type', 'store_city', 'store_state', 'store_sqft', 'grocery_sqft',
#        'frozen_sqft', 'meat_sqft', 'coffee_bar', 'video_store', 'salad_bar',
#        'prepared_food', 'florist', 'media_type', 'cost'],
#       dtype='object')

# %%
df.rename(columns={'store_sales(in millions)':'store_sales_mm', 
                   'store_cost(in millions)':'store_cost_mm',
                   'unit_sales(in millions)': 'unit_sales_mm',
                  'avg_cars_at home(approx)': 'avg_cars', 
                  'avg. yearly_income': 'avg_ann_income'}, inplace=True)

# %%
df.columns
# Out:
# Index(['food_category', 'food_department', 'food_family', 'store_sales_mm',
#        'store_cost_mm', 'unit_sales_mm', 'promotion_name', 'sales_country',
#        'marital_status', 'gender', 'total_children', 'education',
#        'member_card', 'occupation', 'houseowner', 'avg_cars', 'avg_ann_income',
#        'num_children_at_home', 'brand_name', 'SRP', 'store_type', 'store_city',
#        'store_state', 'store_sqft', 'grocery_sqft', 'frozen_sqft', 'meat_sqft',
#        'coffee_bar', 'video_store', 'salad_bar', 'prepared_food', 'florist',
#        'media_type', 'cost'],
#       dtype='object')

# %%
numeric_columns = [c for c in df.columns if df[c].dtype in ['int64', 'float64']]
numeric_columns
# Out:
# ['store_sales_mm',
#  'store_cost_mm',
#  'unit_sales_mm',
#  'total_children',
#  'avg_cars',
#  'num_children_at_home',
#  'SRP',
#  'store_sqft',
#  'grocery_sqft',
#  'frozen_sqft',
#  'meat_sqft',
#  'coffee_bar',
#  'video_store',
#  'salad_bar',
#  'prepared_food',
#  'florist',
#  'cost']

# %%
non_numeric_columns = [c for c in df.columns if c not in numeric_columns]
non_numeric_columns
# Out:
# ['food_category',
#  'food_department',
#  'food_family',
#  'promotion_name',
#  'sales_country',
#  'marital_status',
#  'gender',
#  'education',
#  'member_card',
#  'occupation',
#  'houseowner',
#  'avg_ann_income',
#  'brand_name',
#  'store_type',
#  'store_city',
#  'store_state',
#  'media_type']

# %%
# shouldn't income be numeric? ohh, different format!
df['avg_ann_income'].head()
# Out:
# 0    $10K - $30K
# 1    $50K - $70K
# 2    $10K - $30K
# 3    $30K - $50K
# 4    $30K - $50K
# Name: avg_ann_income, dtype: object

# %%
sns.histplot(data=df, x='avg_ann_income')
plt.xticks(rotation=90)
plt.title('Income Histogram')
plt.show()

# %% [markdown]
# ### 3. Missing Values / Duplicates / Outlier detection

# %%
# missing values? - no
df.isnull().sum().sum()
# Out:
# 0

# %%
# duplicates?
df.duplicated().sum()
# Out:
# 0

# %%
# outliers for first column
Q1_store_sales = df.store_sales_mm.quantile(0.25)
Q3_store_sales = df.store_sales_mm.quantile(0.75)
IQR_store_sales = Q3_store_sales - Q1_store_sales
threshold = 1.5

# %%
# Values for vertical lines
vertical_lines = [Q1_store_sales - threshold * IQR_store_sales, Q3_store_sales + threshold * IQR_store_sales] 

# Create the histogram
plt.hist(df['store_sales_mm'], bins=10, color='blue', alpha=0.7)

# Add vertical lines
for line in vertical_lines:
    plt.axvline(x=line, color='red', linestyle='--', label=f'Line at {line}')

plt.xlabel('Store Sales (millions)')
plt.ylabel('Frequency')
plt.title('Stores Sales with Outlier Lines')
plt.show()

# %%
# all outliers counts

Q1 = df.quantile(0.25, numeric_only=True)
Q3 = df.quantile(0.75, numeric_only=True)
IQR = Q3 - Q1

dict_outliers = {}
for c in numeric_columns:
    dict_outliers[c] = len(df[(df[c] < (Q1 - threshold * IQR)[c]) | (df[c] > (Q3 + threshold * IQR)[c])])

# %%
dict_outliers
# Out:
# {'store_sales_mm': 325,
#  'store_cost_mm': 986,
#  'unit_sales_mm': 890,
#  'total_children': 0,
#  'avg_cars': 0,
#  'num_children_at_home': 8167,
#  'SRP': 0,
#  'store_sqft': 0,
#  'grocery_sqft': 0,
#  'frozen_sqft': 9996,
#  'meat_sqft': 9996,
#  'coffee_bar': 0,
#  'video_store': 0,
#  'salad_bar': 0,
#  'prepared_food': 0,
#  'florist': 0,
#  'cost': 0}

# %%
# 'total_children' vs. 'num_children_at_home'
sns.histplot(data=df, x='total_children')
# Out:
# <Axes: xlabel='total_children', ylabel='Count'>

# %%
sns.histplot(data=df, x='num_children_at_home')
# Out:
# <Axes: xlabel='num_children_at_home', ylabel='Count'>

# %%
# some stores have really big frozen/meat sections, or a tiny one
sns.histplot(data=df, x='meat_sqft')
#sns.histplot(data=df, x='frozen_sqft')
# Out:
# <Axes: xlabel='meat_sqft', ylabel='Count'>

# %%
# be wary of the columns that provide us with a lot of outliers in the analysis going forward

# %% [markdown]
# ### 5. Create some important/relevant metrics as new columns

# %%
# are there always promotions? if not, can compare sales in no promo times to promo times 
df['promotion_name'].value_counts().head()
# Out:
# promotion_name
# Weekend Markdown    2330
# Two Day Sale        2321
# Price Savers        2279
# Price Winners       2108
# Save-It Sale        2001
# Name: count, dtype: int64

# %%
# column for tot store profit 
df['store_profit_mm']= df['store_sales_mm'] - df['store_cost_mm']

# column for store profit per unit 
df['unit_profit_mm']= df['store_profit_mm'] - df['unit_sales_mm']

# %%
df[['store_sales_mm','store_cost_mm','unit_profit_mm','store_profit_mm','unit_sales_mm']].head()
# Out:
#    store_sales_mm  store_cost_mm  unit_profit_mm  store_profit_mm  \
# 0            7.36         2.7232          0.6368           4.6368
# 1            5.52         2.5944         -0.0744           2.9256
# 2            3.68         1.3616          0.3184           2.3184
# 3            3.68         1.1776          0.5024           2.5024
# 4            4.08         1.4280         -0.3480           2.6520
#
#    unit_sales_mm
# 0            4.0
# 1            3.0
# 2            2.0
# 3            2.0
# 4            3.0

# %%
# makes sense that less store make higher profit, the mean is lower
sns.histplot(data=df, x='store_profit_mm')
# Out:
# <Axes: xlabel='store_profit_mm', ylabel='Count'>

# %% [markdown]
# ### 6. Boxplots / Correlation / Pairplot for important numeric variables

# %%
numeric_columns
# Out:
# ['store_sales_mm',
#  'store_cost_mm',
#  'unit_sales_mm',
#  'total_children',
#  'avg_cars',
#  'num_children_at_home',
#  'SRP',
#  'store_sqft',
#  'grocery_sqft',
#  'frozen_sqft',
#  'meat_sqft',
#  'coffee_bar',
#  'video_store',
#  'salad_bar',
#  'prepared_food',
#  'florist',
#  'cost']

# %%
# look at distribution of the numeric variables 
for c in numeric_columns:
    sns.boxplot(data=df, x=c, orient='h') 
    plt.show()

# we see that:
binary_cols = [ 'coffee_bar',
 'video_store',
 'salad_bar',
 'prepared_food',
 'florist',]

# %%
sns.pairplot(df[['cost', 'SRP', 'unit_sales_mm', 'store_sales_mm', 'store_cost_mm' ]],
             diag_kind='kde', height=1.5)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.heatmap(df[numeric_columns].corr())
# Out:
# <Axes: >

# %%
sns.distplot(df['cost'])
# Out:
# /var/folders/8j/sh_q2r0160gcq1f0ttgf9z800000gn/T/ipykernel_3059/1352492925.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cost'])
# <Axes: xlabel='cost', ylabel='Density'>

# %%
non_numeric_columns
# Out:
# ['food_category',
#  'food_department',
#  'food_family',
#  'promotion_name',
#  'sales_country',
#  'marital_status',
#  'gender',
#  'education',
#  'member_card',
#  'occupation',
#  'houseowner',
#  'avg_ann_income',
#  'brand_name',
#  'store_type',
#  'store_city',
#  'store_state',
#  'media_type']

# %% [markdown]
# ### 7. Guiding questions -- do some groupbys, look at distributions

# %% [markdown]
# #### Does it cost more to acquire people that make more annually?
# cost: cost to acquire a customer

# %%
# no
(df.groupby('avg_ann_income')['cost'].sum() /  df.groupby('avg_ann_income')['avg_ann_income'].count()).sort_values()
# Out:
# avg_ann_income
# $70K - $90K       98.014146
# $130K - $150K     98.319229
# $110K - $130K     98.909347
# $150K +           99.129356
# $10K - $30K       99.329848
# $30K - $50K       99.434719
# $90K - $110K      99.641838
# $50K - $70K      100.065537
# dtype: float64

# %% [markdown]
# #### Does it cost more to acquire people in different states by store type?

# %%
sns.barplot(data=df, x='sales_country', y='cost', hue='store_type', estimator='mean', errorbar='sd')
# Out:
# <Axes: xlabel='sales_country', ylabel='cost'>

# %%
df.columns
# Out:
# Index(['food_category', 'food_department', 'food_family', 'store_sales_mm',
#        'store_cost_mm', 'unit_sales_mm', 'promotion_name', 'sales_country',
#        'marital_status', 'gender', 'total_children', 'education',
#        'member_card', 'occupation', 'houseowner', 'avg_cars', 'avg_ann_income',
#        'num_children_at_home', 'brand_name', 'SRP', 'store_type', 'store_city',
#        'store_state', 'store_sqft', 'grocery_sqft', 'frozen_sqft', 'meat_sqft',
#        'coffee_bar', 'video_store', 'salad_bar', 'prepared_food', 'florist',
#        'media_type', 'cost', 'store_profit_mm', 'unit_profit_mm', 'cluster'],
#       dtype='object')

# %% [markdown]
# #### Within USA, largest store per state?

# %%
df[ df["sales_country"] == 'USA'].groupby('store_state')['store_sqft'].max()
# Out:
# store_state
# CA    23688.0
# OR    27694.0
# WA    39696.0
# Name: store_sqft, dtype: float64

# %% [markdown]
# #### In US states, what are the 3 stores with the most sales?

# %%
df[df["store_state"].isin(['CA', 'OR', 'WA'])].nlargest(3, 'store_sales_mm')
# Out:
#         food_category     food_department     food_family  store_sales_mm  \
# 32337     Canned Soup        Canned Foods            Food            19.9
# 42493  Pain Relievers  Health and Hygiene  Non-Consumable            19.9
# 42575  Pain Relievers  Health and Hygiene  Non-Consumable            19.9
#
#        store_cost_mm  unit_sales_mm       promotion_name sales_country  \
# 32337          6.368            5.0         Two Day Sale           USA
# 42493          6.965            5.0         One Day Sale           USA
# 42575          6.567            5.0  Green Light Special           USA
#
#       marital_status gender  ...  coffee_bar video_store salad_bar  \
# 32337              S      M  ...         1.0         1.0       1.0
# 42493              S      F  ...         1.0         1.0       1.0
# 42575              S      F  ...         0.0         0.0       1.0
#
#       prepared_food florist              media_type    cost  store_profit_mm  \
# 32337           1.0     1.0      Daily Paper, Radio  112.52           13.532
# 42493           1.0     1.0  Daily Paper, Radio, TV   85.88           12.935
# 42575           1.0     0.0         In-Store Coupon  123.02           13.333
#
#       unit_profit_mm  cluster
# 32337          8.532        0
# 42493          7.935        1
# 42575          8.333        0
#
# [3 rows x 37 columns]

# %% [markdown]
# #### Which store has the highest sales?

# %%
df[df["store_sales_mm"] == df.store_sales_mm.max()]
# Out:
#       food_category food_department food_family  store_sales_mm  \
# 26755         Fruit         Produce        Food           22.92
#
#        store_cost_mm  unit_sales_mm promotion_name sales_country  \
# 26755         8.7096            6.0   Bye Bye Baby        Canada
#
#       marital_status gender  ...  coffee_bar video_store salad_bar  \
# 26755              S      F  ...         1.0         1.0       1.0
#
#       prepared_food florist    media_type    cost  store_profit_mm  \
# 26755           1.0     1.0  Sunday Paper  138.18          14.2104
#
#       unit_profit_mm  cluster
# 26755         8.2104        2
#
# [1 rows x 37 columns]

# %% [markdown]
# #### Are there specific brands that dominate sales?

# %%
df.groupby('brand_name')['store_sales_mm'].sum().sort_values(ascending=False).nlargest(10)
# Out:
# brand_name
# Hermanos        13169.63
# Tell Tale       11540.20
# Ebony           11130.46
# Tri-State       10665.58
# High Top        10408.71
# Nationeel       10231.83
# Horatio         10133.52
# Best Choice      9369.96
# Fast             9178.11
# High Quality     9036.66
# Name: store_sales_mm, dtype: float64

# %% [markdown]
# ### 8. Conclusion

# %% [markdown]
# Looks like higher store costs mean high Suggested Retail Prices (SRP) and higher store sales. Canada has the store with the highest sales and only seems to have Deluxe and Mid-Size grocery in this dataset. A few columns provide a lot of outliers such as number of children at home and square footage of meat/frozen sections in the stores so it will be good to look out for these columns biasing results when doing further analyses.

# %% [markdown]
# ### Practice Joining tables:

# %%
# create small lookup table for salutations just to practice joining tables 
sals = {
    'houseowner': ['Y', 'Y', 'N', 'N'],
    'gender': ['F', 'M', 'F', 'M'],
    'salutation': ['Mrs', 'Mr', 'Miss', 'Mister']
}

sals_df = pd.DataFrame(sals)

sals_df
# Out:
#   houseowner gender salutation
# 0          Y      F        Mrs
# 1          Y      M         Mr
# 2          N      F       Miss
# 3          N      M     Mister

# %%
#display number of people by salutations 

merged_df = df.merge(sals_df, on=['houseowner', 'gender'], how='left')
merged_df.groupby('salutation')[['houseowner', 'gender']].count()
# Out:
#             houseowner  gender
# salutation
# Miss             12192   12192
# Mister           11726   11726
# Mr               17760   17760
# Mrs              18750   18750
